# %%
arr_1d = [10, 20, 30, 40, 50]

arr_2d = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print("1D Array:")
print(arr_1d)

print("\n2D Array (Matrix):")
for row in arr_2d:
    print(row)
# Out:
# 1D Array:
# [10, 20, 30, 40, 50]
#
# 2D Array (Matrix):
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
