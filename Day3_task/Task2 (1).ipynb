# %%
student_marks = {
    "Prayut Chauhan": 85,
    "Rushabh Shah": 92,
    "Meet Vaja": 78
}

print("Students and Their Marks:\n")

for name, marks in student_marks.items():
    print("Name:", name)
    print("Marks:", marks)
    print()
# Out:
# Students and Their Marks:
#
# Name: Prayut Chauhan
# Marks: 85
#
# Name: Rushabh Shah
# Marks: 92
#
# Name: Meet Vaja
# Marks: 78
